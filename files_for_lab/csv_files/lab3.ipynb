# %%
import pandas as pd

# %%
marcusan = pd.read_csv('marketing_customer_analysis.csv')

cols=[]
for c in marcusan.columns:
    cols.append(c.lower())
marcusan.columns=cols

marcusan = marcusan.drop(['unnamed: 0'], axis=1)
marcusan.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
marcusan.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
marcusan = pd.read_csv('marketing_customer_analysis.csv')

marcusan.describe().T
# Out:
#                                  count          mean           std  \
# Unnamed: 0                     10910.0   5454.500000   3149.590053
# Customer Lifetime Value        10910.0   8018.241094   6885.081434
# Income                         10910.0  37536.284785  30359.195670
# Monthly Premium Auto           10910.0     93.196059     34.442532
# Months Since Last Claim        10277.0     15.149071     10.080349
# Months Since Policy Inception  10910.0     48.091934     27.940675
# Number of Open Complaints      10277.0      0.384256      0.912457
# Number of Policies             10910.0      2.979193      2.399359
# Total Claim Amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# Unnamed: 0                        0.000000  2727.250000   5454.500000
# Customer Lifetime Value        1898.007675  4014.453113   5771.147235
# Income                            0.000000     0.000000  33813.500000
# ...

# %%
marcusan.describe(include='all').T
# Out:
#                                  count unique            top  freq  \
# Unnamed: 0                     10910.0    NaN            NaN   NaN
# Customer                         10910   9134        ID89933     7
# State                            10279      5     California  3552
# Customer Lifetime Value        10910.0    NaN            NaN   NaN
# Response                         10279      2             No  8813
# Coverage                         10910      3          Basic  6660
# Education                        10910      5       Bachelor  3272
# Effective To Date                10910     59        1/10/11   239
# EmploymentStatus                 10910      5       Employed  6789
# Gender                           10910      2              F  5573
# Income                         10910.0    NaN            NaN   NaN
# Location Code                    10910      3       Suburban  6902
# Marital Status                   10910      3        Married  6319
# ...

# %%
marcusan.countplot("Responses")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-fc275763754b> in <module>
# ----> 1 marcusan.countplot("Responses")
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'countplot'

# %%
marcusan['Response'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: Response, dtype: int64

# %%
marcusan['Response'].isna().sum()
# Out:
# 0

# %%
nulls_df =marcusan['Response']
nulls_df
# Out:
# 0         No
# 1         No
# 2         No
# 3        Yes
# 4         No
#         ...
# 10905     No
# 10906     No
# 10907     No
# 10908     No
# 10909    NaN
# Name: Response, Length: 10910, dtype: object

# %%
marcusan['Response'] = marcusan['Response'].fillna(0)

# %%
round(marcusan.isna().sum()/len(marcusan),4)*100
# Out:
# Unnamed: 0                        0.00
# Customer                          0.00
# State                             5.78
# Customer Lifetime Value           0.00
# Response                          0.00
# Coverage                          0.00
# Education                         0.00
# Effective To Date                 0.00
# EmploymentStatus                  0.00
# Gender                            0.00
# Income                            0.00
# Location Code                     0.00
# Marital Status                    0.00
# Monthly Premium Auto              0.00
# Months Since Last Claim           5.80
# Months Since Policy Inception     0.00
# Number of Open Complaints         5.80
# Number of Policies                0.00
# Policy Type                       0.00
# Policy                            0.00
# Renew Offer Type                  0.00
# Sales Channel                     0.00
# Total Claim Amount                0.00
# Vehicle Class                     5.70
# ...

# %%
marcusan.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
sns.displot(marcusan['Response'])
plt.show()

# %%
def response_rate(x):
    if x == 'No':
        return 0
    else:
        return 1

# %%
marcusan['response rate']= marcusan['Response'].apply(lambda x: response_rate(x))
marcusan.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#       Policy Type        Policy Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3           Offer3          Agent
# ...

# %%
sns.barplot(x='response rate', y='Sales Channel', data=marcusan )
plt.show()

# %%
sns.barplot(x='response rate', y='Total Claim Amount', data=marcusan )
plt.show()

# %%
sns.barplot(x='response rate', y='Income', data=marcusan )
plt.show()
