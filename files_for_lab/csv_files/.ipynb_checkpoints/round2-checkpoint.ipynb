# %%
import pandas as pd

# %%
marcusan = pd.read_csv('marketing_customer_analysis.csv')

cols=[]
for c in marcusan.columns:
    cols.append(c.lower())
marcusan.columns=cols

marcusan = marcusan.drop(['unnamed: 0'], axis=1)
marcusan.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
marcusan.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
import pandas as pd
marcusan = pd.read_csv('marketing_customer_analysis.csv')

cols=[]
for c in marcusan.columns:
    cols.append(c.lower())
marcusan.columns=cols

marcusan = marcusan.drop(['unnamed: 0'], axis=1)
marcusan.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
marcusan._get_numeric_data()
marcusan.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
marcusan._get_bool_data()
marcusan.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
marcusan.select_dtypes('object')
marcusan.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
marcusan.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# ...

# %%
nulls_df = pd.DataFrame(round(marcusan.isna().sum()/len(marcusan),4)*100)
nulls_df
# Out:
#                                    0
# customer                        0.00
# state                           5.78
# customer lifetime value         0.00
# response                        5.78
# coverage                        0.00
# education                       0.00
# effective to date               0.00
# employmentstatus                0.00
# gender                          0.00
# income                          0.00
# location code                   0.00
# marital status                  0.00
# monthly premium auto            0.00
# months since last claim         5.80
# months since policy inception   0.00
# number of open complaints       5.80
# number of policies              0.00
# policy type                     0.00
# policy                          0.00
# renew offer type                0.00
# sales channel                   0.00
# total claim amount              0.00
# vehicle class                   5.70
# vehicle size                    5.70
# ...

# %%
print(marcusan.shape)
marcusan = marcusan.drop_duplicates(subset=['state','response','months since last claim','number of open complaints','vehicle class','vehicle size'])
print(marcusan.shape)
# Out:
# (10910, 25)
# (4128, 25)

# %%
import numpy as np
marcusan[marcusan['response'].isna()==True].head(20)
# Out:
#     customer state  customer lifetime value response  coverage  \
# 5    HO81102   NaN              4745.181764      NaN     Basic
# 11   GE63585   NaN              2420.711888      NaN     Basic
# 58   BR69566   NaN             14019.833140      NaN     Basic
# 62   UF44021   NaN              2108.493744      NaN     Basic
# 126  TE60343   NaN              4716.264294      NaN     Basic
# 131  QK24293   NaN              6265.343299      NaN  Extended
# 155  JG35886   NaN              4111.888285      NaN   Premium
# 168  FV22585   NaN              6960.920371      NaN  Extended
# 169  AU23837   NaN              5010.379310      NaN     Basic
# 190  VZ18907   NaN             21991.615980      NaN     Basic
# 226  VK57280   NaN              4727.354548      NaN     Basic
# 251  EA52579   NaN              7687.296987      NaN     Basic
# 270  KX23516   NaN              4455.843406      NaN  Extended
# 304  PP39078   NaN              5623.611187      NaN     Basic
# ...

# %%
marcusan['response'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
marcusan['response'].value_counts()
# Out:
# No     3109
# Yes     682
# Name: response, dtype: int64

# %%
len(marcusan[marcusan['gender'].isna()==True])
# Out:
# 0

# %%
marcusan['response'] = marcusan['response'].fillna('No')

# %%
marcusan[['months since last claim','months since policy inception']]
# Out:
#        months since last claim  months since policy inception
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10891                     10.0                             46
# 10903                     30.0                             82
# 10904                     14.0                             32
# 10905                      NaN                             40
# 10907                     11.0                             63
#
# [4128 rows x 2 columns]
